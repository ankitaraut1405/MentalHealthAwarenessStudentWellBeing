# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Mental Health Awareness.csv')

# %%
df.head()
# Out:
#   What is your age group? What is your current year of study?\n  \
# 0                   19-21                            Third Year
# 1                   22-24                            Third Year
# 2                   19-21                            Third Year
# 3                   19-21                            Third Year
# 4                   22-24                                 Other
#
#    How well do you understand what mental health means?\n  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#       What do you think mental health is related to?  \
# 0  Emotions;Thoughts and feelings;Relationships w...
# 1  Thoughts and feelings;How we handle problems;R...
# 2  Emotions;Thoughts and feelings;Relationships w...
# ...

# %%
df.shape
# Out:
# (74, 22)

# %%
df.columns
# Out:
# Index(['What is your age group?', 'What is your current year of study?\n',
#        'How well do you understand what mental health means?\n',
#        'What do you think mental health is related to?',
#        'Do you think mental health is as important as physical health?\n',
#        'Do you think anyone can experience mental-health difficulties?\n',
#        'Do you know where a student can get help if they are facing emotional or mental difficulties?\n',
#        'If you are feeling emotionally upset or stressed, would you talk to someone?\n',
#        'Who would you feel comfortable talking to when you have a problem?\n',
#        'What makes it difficult for students to talk about their mental health?\n',
#        'Do you think students need more mental-health awareness in college/school?\n',
#        'How often do you feel overwhelmed by your daily responsibilities?',
#        'How often do you feel emotionally tired?\n',
# ...

# %%
df.columns
# Out:
# Index(['What is your age group?', 'What is your current year of study?\n',
#        'How well do you understand what mental health means?\n',
#        'What do you think mental health is related to?',
#        'Do you think mental health is as important as physical health?\n',
#        'Do you think anyone can experience mental-health difficulties?\n',
#        'Do you know where a student can get help if they are facing emotional or mental difficulties?\n',
#        'If you are feeling emotionally upset or stressed, would you talk to someone?\n',
#        'Who would you feel comfortable talking to when you have a problem?\n',
#        'What makes it difficult for students to talk about their mental health?\n',
#        'Do you think students need more mental-health awareness in college/school?\n',
#        'How often do you feel overwhelmed by your daily responsibilities?',
#        'How often do you feel emotionally tired?\n',
# ...

# %%
df.isnull().sum()
# Out:
# What is your age group?                                                                             0
# What is your current year of study?\n                                                               0
# How well do you understand what mental health means?\n                                              0
# What do you think mental health is related to?                                                      0
# Do you think mental health is as important as physical health?\n                                    0
# Do you think anyone can experience mental-health difficulties?\n                                    0
# Do you know where a student can get help if they are facing emotional or mental difficulties?\n     0
# If you are feeling emotionally upset or stressed, would you talk to someone?\n                      0
# Who would you feel comfortable talking to when you have a problem?\n                                0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df["What is your age group?"].value_counts())
# Out:
# What is your age group?
# 19-21      39
# 22-24      21
# 17 - 18    11
# 25-27       3
# Name: count, dtype: int64

# %%
print(df.iloc[:, 0].value_counts())
# Out:
# What is your age group?
# 19-21      39
# 22-24      21
# 17 - 18    11
# 25-27       3
# Name: count, dtype: int64

# %%
print(df.iloc[:, 1].value_counts())
# Out:
# What is your current year of study?\n
# Third Year     30
# Second Year    21
# Other          20
# First Year      3
# Name: count, dtype: int64

# %%
df.iloc[:, 0].value_counts().plot(kind="bar")

plt.title("Age Group of Respondents")
plt.xlabel("Age Group")
plt.ylabel("Number of Students")
plt.show()

# %%
df.iloc[:, 1].value_counts().plot(kind="bar")

plt.title("Year of Study of Students")
plt.xlabel("Year of Study")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 2].value_counts())
# Out:
# How well do you understand what mental health means?\n
# 5    28
# 4    16
# 3    15
# 1     9
# 2     6
# Name: count, dtype: int64

# %%
df.iloc[:, 2].value_counts().plot(kind="bar")

plt.title("Understanding of Mental Health")
plt.xlabel("Understanding Level")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 3].value_counts())
# Out:
# What do you think mental health is related to?
# Thoughts and feelings                                                                       14
# All of the above                                                                            10
# Emotions                                                                                     9
# Emotions;Thoughts and feelings;Relationships with others                                     8
# Emotions;Thoughts and feelings;How we handle problems;Relationships with others              6
# How we handle problems                                                                       6
# Relationships with others                                                                    5
# Not sure                                                                                     4
# Thoughts and feelings;How we handle problems;Relationships with others                       2
# ...

# %%
df.iloc[:, 3].value_counts().plot(kind="bar")

plt.title("What Students Think Mental Health Is Related To")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 4].value_counts())
# Out:
# Do you think mental health is as important as physical health?\n
# Yes         52
# No          16
# Not sure     6
# Name: count, dtype: int64

# %%
df.iloc[:, 4].value_counts().plot(kind="bar")

plt.title("Importance of Mental Health Compared with Physical Health")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 5].value_counts())
# Out:
# Do you think anyone can experience mental-health difficulties?\n
# Yes         46
# No          16
# Not sure    12
# Name: count, dtype: int64

# %%
df.iloc[:, 5].value_counts().plot(kind="bar")

plt.title("Awareness That Mental-Health Difficulties Can Affect Anyone")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 6].value_counts())
# Out:
# Do you know where a student can get help if they are facing emotional or mental difficulties?\n
# Yes         42
# No          22
# Not sure    10
# Name: count, dtype: int64

# %%
df.iloc[:, 6].value_counts().plot(kind="bar")

plt.title("Knowledge of Mental-Health Support")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 7].value_counts())
# Out:
# If you are feeling emotionally upset or stressed, would you talk to someone?\n
# Yes      45
# No       21
# Maybe     8
# Name: count, dtype: int64

# %%
df.iloc[:, 7].value_counts().plot(kind="bar")

plt.title("Willingness to Talk About Mental Health")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 8].value_counts())
# Out:
# Who would you feel comfortable talking to when you have a problem?\n
# Friend                            20
# Parents/Family;Friend             18
# Parents/Family                    15
# No one                            12
# Teacher;No one                     2
# No one;                            1
# Parents/Family;                    1
# Parents/Family;Friend;Teacher      1
# Friend;No one                      1
# Counsellor                         1
# Teacher                            1
# Parents/Family;Friend;Teacher;     1
# Name: count, dtype: int64

# %%
df.iloc[:, 8].value_counts().plot(kind="bar")

plt.title("People Students Would Talk To")
plt.xlabel("Person")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 9].value_counts())
# Out:
# What makes it difficult for students to talk about their mental health?\n
# Fear of being judged                                                                                                                                               14
# Fear of being judged;Family may not understand                                                                                                                     10
# Feeling shy or uncomfortable                                                                                                                                        6
# Fear of being judged;Family may not understand;Feeling shy or uncomfortable                                                                                         5
# I don't think it is important                                                                                                                                       4
# ...

# %%
df.iloc[:, 9].value_counts().plot(kind="bar")

plt.title("Barriers to Talking About Mental Health")
plt.xlabel("Barrier")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 10].value_counts())
# Out:
# Do you think students need more mental-health awareness in college/school?\n
# Yes         55
# No          12
# Not sure     7
# Name: count, dtype: int64

# %%
df.iloc[:, 10].value_counts().plot(kind="bar")

plt.title("Need for More Mental Health Awareness")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 11].value_counts())
# Out:
# How often do you feel overwhelmed by your daily responsibilities?
# 5    24
# 4    19
# 3    15
# 2     9
# 1     7
# Name: count, dtype: int64

# %%
df.iloc[:, 11].value_counts().plot(kind="bar")

plt.title("How Often Students Feel Overwhelmed")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 12].value_counts())
# Out:
# How often do you feel emotionally tired?\n
# 5    21
# 3    19
# 4    17
# 1     9
# 2     8
# Name: count, dtype: int64

# %%
df.iloc[:, 12].value_counts().plot(kind="bar")

plt.title("Emotional Tiredness Among Students")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 13].value_counts())
# Out:
# How supported do you feel by the people around you?\n
# 5    20
# 3    18
# 4    15
# 1    14
# 2     7
# Name: count, dtype: int64

# %%
df.iloc[:, 13].value_counts().plot(kind="bar")

plt.title("Students' Perceived Social Support")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 14].value_counts())
# Out:
# What usually helps you when you are having a difficult day?\n
# Listening to music                                                                                         9
# Talking to someone                                                                                         7
# Rest/sleep                                                                                                 4
# Taking a break                                                                                             4
# Rest/sleep;Spending time with friends/family                                                               4
# Spending time with friends/family                                                                          4
# Hobbies                                                                                                    3
# Talking to someone;Taking a break;Listening to music                                                       2
# ...

# %%
df.iloc[:, 14].value_counts().plot(kind="bar")

plt.title("What Helps Students on Difficult Days")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 15].value_counts())
# Out:
# How much academic pressure do you usually feel?\n
# 5    27
# 3    15
# 4    15
# 1    12
# 2     5
# Name: count, dtype: int64

# %%
df.iloc[:, 15].value_counts().plot(kind="bar")

plt.title("Academic Pressure Among Students")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 16].value_counts())
# Out:
# How many hours do you usually sleep per night?\n
# 5–6 hours            28
# 6–7 hours            27
# 7–8 hours            10
# Less than 5 hours     7
# More than 8 hours     2
# Name: count, dtype: int64

# %%
df.iloc[:, 16].value_counts().plot(kind="bar")

plt.title("Sleep Duration of Students")
plt.xlabel("Sleep Duration")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 17].value_counts())
# Out:
# Approximately how much screen time do you have per day?\n
# 4–6 hours            34
# 2–4 hours            17
# Less than 2 hours    13
# 6–8 hours             7
# More than 8 hours     3
# Name: count, dtype: int64

# %%
df.iloc[:, 17].value_counts().plot(kind="bar")

plt.title("Daily Screen Time")
plt.xlabel("Screen Time")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 18].value_counts())
# Out:
# How often do you participate in physical activity or exercise?\n
# Never                    32
# Rarely                   24
# 1–2 days a week          11
# 3–4 days a week           4
# 5 or more days a week     3
# Name: count, dtype: int64

# %%
df.iloc[:, 18].value_counts().plot(kind="bar")

plt.title("Physical Activity Among Students")
plt.xlabel("Frequency")
plt.ylabel("Number of Students")
plt.show()

# %%
print(df.iloc[:, 19].dropna())
# Out:
# 0                             the stress get from study
# 2                                           Keep smile
# 3              Listening music and ignoring bad people
# 4                                              Nothing
# 6            Understanding and solving problems easily
# 8                                 Depression & Anxiety
# 9                                                     .
# 10                                                Yes\n
# 11                                                  ..
# 15    Good mental health means feeling emotionally b...
# 17         Having a stree free life or a relax mind set
# 19    Good mental health means feeling emotionally b...
# 21    Good mental health means feeling emotionally b...
# 22                     Peace alone happy with yourself
# 23    Good mental health means being able to stay ca...
# 24                                      Very important
# 25    It means being emotionally balanced, confident...
# ...

# %%
print(df.iloc[:, 20].dropna())
# Out:
# 0                                                   yes
# 2                                    Talk with suspect
# 3                    To solve our problem and quarries
# 4                                              Nothing
# 6                                              No idea
# 8     Noo . \nTeachers do care only about academic c...
# 9                                                     .
# 10                                                 No\n
# 11                                                  Yes
# 15    I wish parents and teachers understood that st...
# 17                                                  Yes
# 19    I wish parents and teachers understood that st...
# 21    I wish parents and teachers understood that st...
# 22     To parent  or teacher  Understand a students ...
# 23    I wish parents and teachers understood that st...
# 24                            No they never understand
# 25    I wish they would listen to students without j...
# ...

# %%
print(df.iloc[:, 21].dropna())
# Out:
# 0                                      yes they need it
# 2                                                   Yes
# 3                                                   Yes
# 4                                                   Yes
# 6                                                 Yess
# 8     Talk to self and get motivation through self. ...
# 9                                                     .
# 10                                                  Yes
# 11                                                  Yes
# 15    Students need more open discussions, awareness...
# 17                                                 Yes
# 19    Students need more open discussions, mental-he...
# 21    Students need more awareness programs, open di...
# 22    Stop overthinking and not think  you are alone...
# 23    Students need more awareness programs, counsel...
# 24                  Yes they need most according to me
# 25    \nStudents need more awareness programs, works...
# ...

# %%
print(pd.crosstab(df.iloc[:, 15], df.iloc[:, 11]))
# Out:
# How often do you feel overwhelmed by your daily responsibilities?  1  2  3  4  \
# How much academic pressure do you usually feel?\n
# 1                                                                  5  3  1  3
# 2                                                                  0  2  0  1
# 3                                                                  1  1  9  3
# 4                                                                  1  2  3  6
# 5                                                                  0  1  2  6
#
# How often do you feel overwhelmed by your daily responsibilities?   5
# How much academic pressure do you usually feel?\n
# 1                                                                   0
# 2                                                                   2
# 3                                                                   1
# 4                                                                   3
# ...

# %%
print(pd.crosstab(df.iloc[:, 15], df.iloc[:, 12]))
# Out:
# How often do you feel emotionally tired?
#           1  2  3  4   5
# How much academic pressure do you usually feel?\n
# 1                                                  6  1  3  2   0
# 2                                                  0  2  1  0   2
# 3                                                  1  2  9  3   0
# 4                                                  2  2  3  6   2
# 5                                                  0  1  3  6  17

# %%
print(pd.crosstab(df.iloc[:, 16], df.iloc[:, 15]))
# Out:
# How much academic pressure do you usually feel?
#   1  2  3  4   5
# How many hours do you usually sleep per night?\n
# 5–6 hours                                         4  2  9  4   9
# 6–7 hours                                         2  0  4  7  14
# 7–8 hours                                         2  1  0  3   4
# Less than 5 hours                                 3  2  2  0   0
# More than 8 hours                                 1  0  0  1   0

# %%
print(pd.crosstab(df.iloc[:, 13], df.iloc[:, 7]))
# Out:
# If you are feeling emotionally upset or stressed, would you talk to someone?
#   Maybe  \
# How supported do you feel by the people around ...
# 1                                                                                  0
# 2                                                                                  0
# 3                                                                                  2
# 4                                                                                  5
# 5                                                                                  1
#
# If you are feeling emotionally upset or stressed, would you talk to someone?
#   No  \
# How supported do you feel by the people around ...
# 1                                                                               9
# 2                                                                               3
# 3                                                                               5
# ...

# %%
table = pd.crosstab(
    df.iloc[:, 15],
    df.iloc[:, 11],
    normalize="index"
) * 100

print(table.round(1))
# Out:
# How often do you feel overwhelmed by your daily responsibilities?     1     2  \
# How much academic pressure do you usually feel?\n
# 1                                                                  41.7  25.0
# 2                                                                   0.0  40.0
# 3                                                                   6.7   6.7
# 4                                                                   6.7  13.3
# 5                                                                   0.0   3.7
#
# How often do you feel overwhelmed by your daily responsibilities?     3     4  \
# How much academic pressure do you usually feel?\n
# 1                                                                   8.3  25.0
# 2                                                                   0.0  20.0
# 3                                                                  60.0  20.0
# 4                                                                  20.0  40.0
# ...

# %%
pd.crosstab(
    df.iloc[:, 15],
    df.iloc[:, 11]
).plot(kind="bar")

plt.title("Academic Pressure vs Feeling Overwhelmed")
plt.xlabel("Academic Pressure")
plt.ylabel("Number of Students")
plt.show()

# %%
pd.crosstab(
    df.iloc[:, 15],
    df.iloc[:, 12]
).plot(kind="bar")

plt.title("Academic Pressure vs Emotional Tiredness")
plt.xlabel("Academic Pressure")
plt.ylabel("Number of Students")
plt.show()

# %%
# Sleep Duration vs Academic Pressure

sleep_pressure = pd.crosstab(
    df.iloc[:, 16],
    df.iloc[:, 15]
)

print(sleep_pressure)
# Out:
# How much academic pressure do you usually feel?
#   1  2  3  4   5
# How many hours do you usually sleep per night?\n
# 5–6 hours                                         4  2  9  4   9
# 6–7 hours                                         2  0  4  7  14
# 7–8 hours                                         2  1  0  3   4
# Less than 5 hours                                 3  2  2  0   0
# More than 8 hours                                 1  0  0  1   0

# %%
sleep_pressure.plot(kind="bar")

plt.title("Sleep Duration vs Academic Pressure")
plt.xlabel("Sleep Duration")
plt.ylabel("Number of Students")
plt.show()

# %%
# Social Support vs Willingness to Talk

support_talk = pd.crosstab(
    df.iloc[:, 13],
    df.iloc[:, 7]
)

print(support_talk)
# Out:
# If you are feeling emotionally upset or stressed, would you talk to someone?
#   Maybe  \
# How supported do you feel by the people around ...
# 1                                                                                  0
# 2                                                                                  0
# 3                                                                                  2
# 4                                                                                  5
# 5                                                                                  1
#
# If you are feeling emotionally upset or stressed, would you talk to someone?
#   No  \
# How supported do you feel by the people around ...
# 1                                                                               9
# 2                                                                               3
# 3                                                                               5
# ...

# %%
support_talk.plot(kind="bar")

plt.title("Social Support vs Willingness to Talk")
plt.xlabel("Social Support")
plt.ylabel("Number of Students")
plt.show()

# %%
pressure_overwhelmed = pd.crosstab(
    df.iloc[:, 15],
    df.iloc[:, 11]
)

pressure_overwhelmed.plot(kind="bar")

plt.title("Academic Pressure vs Feeling Overwhelmed")
plt.xlabel("Academic Pressure")
plt.ylabel("Number of Students")
plt.show()

# %%
pressure_tired = pd.crosstab(
    df.iloc[:, 15],
    df.iloc[:, 12]
)

pressure_tired.plot(kind="bar")

plt.title("Academic Pressure vs Emotional Tiredness")
plt.xlabel("Academic Pressure")
plt.ylabel("Number of Students")
plt.show()

# %%
age_percentage = df.iloc[:, 0].value_counts(normalize=True) * 100

print(age_percentage.round(1))
# Out:
# What is your age group?
# 19-21      52.7
# 22-24      28.4
# 17 - 18    14.9
# 25-27       4.1
# Name: proportion, dtype: float64

# %%
awareness_percentage = df.iloc[:, 2].value_counts(normalize=True) * 100

print(awareness_percentage.round(1))
# Out:
# How well do you understand what mental health means?\n
# 5    37.8
# 4    21.6
# 3    20.3
# 1    12.2
# 2     8.1
# Name: proportion, dtype: float64

# %%
overwhelmed_percentage = df.iloc[:, 11].value_counts(normalize=True) * 100

print(overwhelmed_percentage.round(1))
# Out:
# How often do you feel overwhelmed by your daily responsibilities?
# 5    32.4
# 4    25.7
# 3    20.3
# 2    12.2
# 1     9.5
# Name: proportion, dtype: float64

# %%
pressure_percentage = df.iloc[:, 15].value_counts(normalize=True) * 100

print(pressure_percentage.round(1))
# Out:
# How much academic pressure do you usually feel?\n
# 5    36.5
# 3    20.3
# 4    20.3
# 1    16.2
# 2     6.8
# Name: proportion, dtype: float64

# %%
percentage_table = pd.crosstab(
    df.iloc[:, 15],
    df.iloc[:, 11],
    normalize="index"
) * 100

print(percentage_table.round(1))
# Out:
# How often do you feel overwhelmed by your daily responsibilities?     1     2  \
# How much academic pressure do you usually feel?\n
# 1                                                                  41.7  25.0
# 2                                                                   0.0  40.0
# 3                                                                   6.7   6.7
# 4                                                                   6.7  13.3
# 5                                                                   0.0   3.7
#
# How often do you feel overwhelmed by your daily responsibilities?     3     4  \
# How much academic pressure do you usually feel?\n
# 1                                                                   8.3  25.0
# 2                                                                   0.0  20.0
# 3                                                                  60.0  20.0
# 4                                                                  20.0  40.0
# ...

# %%
percentage_table.plot(kind="bar")

plt.title("Academic Pressure vs Feeling Overwhelmed (%)")
plt.xlabel("Academic Pressure")
plt.ylabel("Percentage of Students")
plt.show()

# %%
good_mental_health = df.iloc[:, 19].dropna()

print(good_mental_health)
# Out:
# 0                             the stress get from study
# 2                                           Keep smile
# 3              Listening music and ignoring bad people
# 4                                              Nothing
# 6            Understanding and solving problems easily
# 8                                 Depression & Anxiety
# 9                                                     .
# 10                                                Yes\n
# 11                                                  ..
# 15    Good mental health means feeling emotionally b...
# 17         Having a stree free life or a relax mind set
# 19    Good mental health means feeling emotionally b...
# 21    Good mental health means feeling emotionally b...
# 22                     Peace alone happy with yourself
# 23    Good mental health means being able to stay ca...
# 24                                      Very important
# 25    It means being emotionally balanced, confident...
# ...

# %%
parent_teacher = df.iloc[:, 20].dropna()

print(parent_teacher)
# Out:
# 0                                                   yes
# 2                                    Talk with suspect
# 3                    To solve our problem and quarries
# 4                                              Nothing
# 6                                              No idea
# 8     Noo . \nTeachers do care only about academic c...
# 9                                                     .
# 10                                                 No\n
# 11                                                  Yes
# 15    I wish parents and teachers understood that st...
# 17                                                  Yes
# 19    I wish parents and teachers understood that st...
# 21    I wish parents and teachers understood that st...
# 22     To parent  or teacher  Understand a students ...
# 23    I wish parents and teachers understood that st...
# 24                            No they never understand
# 25    I wish they would listen to students without j...
# ...

# %%
awareness_improvement = df.iloc[:, 21].dropna()

print(awareness_improvement)
# Out:
# 0                                      yes they need it
# 2                                                   Yes
# 3                                                   Yes
# 4                                                   Yes
# 6                                                 Yess
# 8     Talk to self and get motivation through self. ...
# 9                                                     .
# 10                                                  Yes
# 11                                                  Yes
# 15    Students need more open discussions, awareness...
# 17                                                 Yes
# 19    Students need more open discussions, mental-he...
# 21    Students need more awareness programs, open di...
# 22    Stop overthinking and not think  you are alone...
# 23    Students need more awareness programs, counsel...
# 24                  Yes they need most according to me
# 25    \nStudents need more awareness programs, works...
# ...

# %%
print("Q20 - Good Mental Health")
print(df.iloc[:, 19].dropna().to_string(index=False))

print("\nQ21 - Parents/Teachers")
print(df.iloc[:, 20].dropna().to_string(index=False))

print("\nQ22 - Improving Awareness")
print(df.iloc[:, 21].dropna().to_string(index=False))
# Out:
# Q20 - Good Mental Health
#                          the stress get from study
#                                        Keep smile
#           Listening music and ignoring bad people
#                                           Nothing
#         Understanding and solving problems easily
#                              Depression & Anxiety
#                                                  .
#                                              Yes\n
#                                                ..
# Good mental health means feeling emotionally ba...
#       Having a stree free life or a relax mind set
# Good mental health means feeling emotionally ba...
# Good mental health means feeling emotionally ba...
#                   Peace alone happy with yourself
# Good mental health means being able to stay cal...
#                                    Very important
# It means being emotionally balanced, confident,...
#                                       Good nature
# ...

# %%
print("Q21 - Parents/Teachers")
print(df.iloc[:, 20].dropna().to_string(index=False))
# Out:
# Q21 - Parents/Teachers
#                                                yes
#                                 Talk with suspect
#                 To solve our problem and quarries
#                                           Nothing
#                                           No idea
# Noo . \nTeachers do care only about academic ca...
#                                                  .
#                                               No\n
#                                                Yes
# I wish parents and teachers understood that stu...
#                                                Yes
# I wish parents and teachers understood that stu...
# I wish parents and teachers understood that stu...
#  To parent  or teacher  Understand a students m...
# I wish parents and teachers understood that stu...
#                          No they never understand
# I wish they would listen to students without ju...
# Teachers must understand the mental health of s...

# %%
print("Q22 - Improving Awareness")
print(df.iloc[:, 21].dropna().to_string(index=False))
# Out:
# Q22 - Improving Awareness
#                                   yes they need it
#                                                Yes
#                                                Yes
#                                                Yes
#                                              Yess
# Talk to self and get motivation through self. B...
#                                                  .
#                                                Yes
#                                                Yes
# Students need more open discussions, awareness ...
#                                               Yes
# Students need more open discussions, mental-hea...
# Students need more awareness programs, open dis...
# Stop overthinking and not think  you are alone ...
# Students need more awareness programs, counseli...
#                Yes they need most according to me
# \nStudents need more awareness programs, worksh...
#                                                 No
# ...

# %%
print("Age Group:")
print(df.iloc[:, 0].value_counts().head(1))

print("\nMental Health Understanding:")
print(df.iloc[:, 2].value_counts().head(1))

print("\nFeeling Overwhelmed:")
print(df.iloc[:, 11].value_counts().head(1))

print("\nEmotional Tiredness:")
print(df.iloc[:, 12].value_counts().head(1))

print("\nAcademic Pressure:")
print(df.iloc[:, 15].value_counts().head(1))

print("\nSleep Duration:")
print(df.iloc[:, 16].value_counts().head(1))
# Out:
# Age Group:
# What is your age group?
# 19-21    39
# Name: count, dtype: int64
#
# Mental Health Understanding:
# How well do you understand what mental health means?\n
# 5    28
# Name: count, dtype: int64
#
# Feeling Overwhelmed:
# How often do you feel overwhelmed by your daily responsibilities?
# 5    24
# Name: count, dtype: int64
#
# Emotional Tiredness:
# How often do you feel emotionally tired?\n
# 5    21
# Name: count, dtype: int64
#
# Academic Pressure:
# How much academic pressure do you usually feel?\n
# 5    27
# Name: count, dtype: int64
#
# Sleep Duration:
# How many hours do you usually sleep per night?\n
# 5–6 hours    28
# Name: count, dtype: int64

# %%
df.iloc[:, 11].value_counts().plot(kind="bar")

plt.title("Students Feeling Overwhelmed")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()

# %%
df.iloc[:, 15].value_counts().plot(kind="bar")

plt.title("Academic Pressure Among Students")
plt.xlabel("Response")
plt.ylabel("Number of Students")
plt.show()
